# %% [markdown]
# # DABsDemoGithub
#
# Trivial notebook executed by `DABsDemoGithub_job`, deployed via Databricks Asset Bundles + GitHub Actions (Workload Identity Federation).
#
# The point of this demo is the CI/CD wiring, not the workload.

# %%
import datetime, platform

print(f"Hello from DABsDemoGithub_job!")
print(f"Run time (UTC):     {datetime.datetime.utcnow().isoformat()}")
print(f"Python version:     {platform.python_version()}")
print(f"Deployed from:      GitHub Actions + Databricks Asset Bundles")
print(f"Authenticated via:  Workload Identity Federation (no PAT secrets!)")
print("Additional text:  demo-edit-2")
